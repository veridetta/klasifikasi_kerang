# %% [markdown]
# # **Viewing classes in Directory**

# %%
import os
import matplotlib.pyplot as plt
from PIL import Image
import math

dir_example = "Data"

classes = os.listdir(dir_example)
print(classes)
# Out:
# ['README.md', 'Test', 'Train']

# %%
dir_example = "Data/Train"

train_classes = os.listdir(dir_example)
print(train_classes)
# Out:
# ['bulu', 'darah']

# %% [markdown]
# # **Visualizing Images in Dataset from each class**

# %%
dir_with_examples = 'visualize'
files_per_row = 2
files_in_dir = os.listdir(dir_with_examples)
number_of_cols = files_per_row
number_of_rows = int(len(files_in_dir) / number_of_cols)

# Generate the subplots
fig, axs = plt.subplots(number_of_rows, number_of_cols)
fig.set_size_inches(20, 15, forward=True)

# Map each file to subplot
try:
  for i in range(0, len(files_in_dir)):
    file_name = files_in_dir[i]
    image = Image.open(f'{dir_with_examples}/{file_name}')
    row = math.floor(i / files_per_row)
    col = i % files_per_row
    axs[col].imshow(image)
    axs[col].axis('off')
except:
  pass
# Show the plot
plt.show()

# %% [markdown]
# # **Importing required Libraries for Model**

# %%
from tensorflow.keras.models import Sequential
from keras.layers import Conv2D, Flatten, MaxPooling2D, Dense, Dropout, SpatialDropout2D
from tensorflow.keras.losses import sparse_categorical_crossentropy, binary_crossentropy
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %% [markdown]
# # **Data Configuration**

# %%
train = 'Data/Train'
test = 'Data/Test'

# %% [markdown]
# # **Data Preparation and Loading**

# %% [markdown]
# ### *Creating a Generator for Training Set*

# %%
train_generator = ImageDataGenerator(rescale = 1/255)

train_generator = train_generator.flow_from_directory(train,
                                                      target_size = (300,300),
                                                      batch_size = 32,
                                                      class_mode = 'sparse')

labels = (train_generator.class_indices)
print(labels,'\n')

labels = dict((v,k) for k,v in labels.items())
print(labels)
# Out:
# Found 480 images belonging to 2 classes.
# {'bulu': 0, 'darah': 1}
#
# {0: 'bulu', 1: 'darah'}

# %% [markdown]
# ### *Creating a Generator for Testing Set*

# %%
test_generator = ImageDataGenerator(rescale = 1./255)

test_generator = test_generator.flow_from_directory(test,
                                                    target_size = (300,300),
                                                    batch_size = 32,
                                                    class_mode = 'sparse')

test_labels = (test_generator.class_indices)
print(test_labels,'\n')

test_labels = dict((v,k) for k,v in test_labels.items())
print(test_labels)
# Out:
# Found 120 images belonging to 2 classes.
# {'bulu': 0, 'darah': 1}
#
# {0: 'bulu', 1: 'darah'}

# %%
for image_batch, label_batch in train_generator:
  break
image_batch.shape, label_batch.shape
# Out:
# ((32, 300, 300, 3), (32,))

# %%
for image_batch, label_batch in test_generator:
  break
image_batch.shape, label_batch.shape
# Out:
# ((32, 300, 300, 3), (32,))

# %% [markdown]
# # **Writing the labels into a text file '*Labels.txt* '**

# %%
print(train_generator.class_indices)
Labels = '\n'.join(sorted(train_generator.class_indices.keys()))

with open('Labels.txt', 'w') as file:
  file.write(Labels)
# Out:
# {'bulu': 0, 'darah': 1}

# %% [markdown]
# # **Model Architecture**

# %%
model=Sequential()

#Convolution blocks
model.add(Conv2D(32, kernel_size = (3,3), padding='same',input_shape=(300,300,3),activation='relu'))
model.add(MaxPooling2D(pool_size=2)) 

model.add(Conv2D(64, kernel_size = (3,3), padding='same',activation='relu'))
model.add(MaxPooling2D(pool_size=2)) 

model.add(Conv2D(32, kernel_size = (3,3), padding='same',activation='relu'))
model.add(MaxPooling2D(pool_size=2)) 

#Classification layers
model.add(Flatten())

model.add(Dense(64,activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(32,activation='relu'))

model.add(Dropout(0.2))
model.add(Dense(6,activation='softmax'))


model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 300, 300, 32)      896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 150, 150, 32)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 150, 150, 64)      18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 75, 75, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 75, 75, 32)        18464
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 37, 37, 32)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 43808)             0
# _________________________________________________________________
# dense (Dense)                (None, 64)                2803776
# _________________________________________________________________
# dropout (Dropout)            (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 6)                 198
# =================================================================
# Total params: 2,843,910
# Trainable params: 2,843,910
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # **Model Compilation**

# %%
model.compile(optimizer = 'Adam', loss = 'sparse_categorical_crossentropy', metrics = ['accuracy'])

# %% [markdown]
# # **Training the Model (batch_size = 32, epochs = 10)**

# %%
model.fit_generator(train_generator,
          epochs=10,
          steps_per_epoch=480//32)
# Out:
# Epoch 1/10
# 15/15 [==============================] - 240s 17s/step - loss: 0.6702 - accuracy: 0.6542
# Epoch 2/10
# 15/15 [==============================] - 208s 14s/step - loss: 0.5031 - accuracy: 0.7875
# Epoch 3/10
# 15/15 [==============================] - 232s 15s/step - loss: 0.3791 - accuracy: 0.8438
# Epoch 4/10
# 15/15 [==============================] - 83s 6s/step - loss: 0.2992 - accuracy: 0.8667
# Epoch 5/10
# 15/15 [==============================] - 91s 6s/step - loss: 0.3418 - accuracy: 0.8750
# Epoch 6/10
# 15/15 [==============================] - 71s 5s/step - loss: 0.1647 - accuracy: 0.9229
# Epoch 7/10
# 15/15 [==============================] - 72s 5s/step - loss: 0.1734 - accuracy: 0.9312
# Epoch 8/10
# 15/15 [==============================] - 74s 5s/step - loss: 0.2184 - accuracy: 0.9208
# Epoch 9/10
# 15/15 [==============================] - 75s 5s/step - loss: 0.1446 - accuracy: 0.9500
# Epoch 10/10
# 15/15 [==============================] - 75s 5s/step - loss: 0.0654 - accuracy: 0.9833

# %% [markdown]
# # **Testing Predictions**

# %%
# from keras.preprocessing import image
import tensorflow.keras.preprocessing.image as im
import keras.utils as ku
import numpy as np
test_img = r'Data\Test\bulu\bulu23.jpg'
img = im.load_img(test_img, target_size = (300,300))
img = im.img_to_array(img, dtype=np.uint8)
img = np.array(img)/255.0
prediction = model.predict(img[np.newaxis, ...])

#print("Predicted shape",p.shape)
print("Probability:",np.max(prediction[0], axis=-1))
predicted_class = labels[np.argmax(prediction[0], axis=-1)]
print("Classified:",predicted_class,'\n')

plt.axis('off')
plt.imshow(img.squeeze())
plt.title("Loaded Image")
# Out:
# Probability: 0.9972187
# Classified: bulu
# Text(0.5, 1.0, 'Loaded Image')

# %%
classes = []
probability = []

for i,j in enumerate(prediction[0],0):
  print(labels[i].upper(),':',round(j*100,2),'%')
# Out:
# BULU : 99.72 %
# DARAH : 0.27 %
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-27-be2a7d6def98> in <module>
#       3
#       4 for i,j in enumerate(prediction[0],0):
# ----> 5   print(labels[i].upper(),':',round(j*100,2),'%')
#
# KeyError: 2

# %%
test_img = r'Data/Test/darah/darah22.png'
img = im.load_img(test_img, target_size = (300,300))
img = im.img_to_array(img, dtype=np.uint8)
img = np.array(img)/255.0
prediction = model.predict(img[np.newaxis, ...])

#print("Predicted shape",p.shape)
print("Probability:",np.max(prediction[0], axis=-1))
predicted_class = labels[np.argmax(prediction[0], axis=-1)]
print("Classified:",predicted_class,'\n')

plt.axis('off')
plt.imshow(img.squeeze())
plt.title("Loaded Image")
# Out:
# Probability: 0.99992764
# Classified: darah
# Text(0.5, 1.0, 'Loaded Image')

# %%
classes = []
probability = []

for i,j in enumerate(prediction[0],0):
  print(labels[i].upper(),':',round(j*100,2),'%')
# Out:
# BULU : 0.01 %
# DARAH : 99.99 %
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-31-be2a7d6def98> in <module>
#       3
#       4 for i,j in enumerate(prediction[0],0):
# ----> 5   print(labels[i].upper(),':',round(j*100,2),'%')
#
# KeyError: 2

# %% [markdown]
# ### *Testing shows that the model is fairly successful in classifying the type of waste*

# %% [markdown]
# ## ***Saving model as 'model.h5'***

# %%
model.save('weights/model.h5')
